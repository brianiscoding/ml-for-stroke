# %%
from matplotlib import pyplot as plt
from sklearn import tree
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
# get and clean data
strokedata = pd.read_csv("stroke_data.csv")

# replacing null BMI values with median value
strokedata["bmi"].fillna(strokedata["bmi"].median(), inplace=True)
# drop instance with Other gender
strokedata = strokedata.drop(strokedata[strokedata["gender"] == "Other"].index)
# drop useless columns
strokedata = strokedata.drop(
    [
        "id"
    ],
    axis=1,
)
# create one-hot encoding
strokedata = pd.get_dummies(strokedata, columns=["smoking_status", 'work_type', 'Residence_type', 'ever_married', 'gender'])
strokedata = strokedata.drop(
    [ 
        'work_type_Govt_job',
        'Residence_type_Urban',
        'smoking_status_smokes',
        'smoking_status_Unknown',
        'ever_married_No',
        'Residence_type_Rural',
        'work_type_Private',
        'heart_disease',
        'smoking_status_never smoked',
        'work_type_children',
        'ever_married_Yes',
        'hypertension'
    ],
    axis=1,
)


len(strokedata.columns)
X = strokedata.iloc[:, 0:8]

# %%
#Splitting into training and testing sets
train_set, test_set = train_test_split(strokedata, test_size=.15, stratify=strokedata["stroke"], random_state=42)


#Creating input and label data
target = 'stroke'
X_train = train_set.drop(target, axis=1)
X_test = test_set.drop(target, axis=1)
y_train = train_set[target]
y_test = test_set[target]

count = Counter(y_train)

# %%
# preprocess
# scale
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# oversample
oversample = SMOTE()
X_train, y_train = oversample.fit_resample(X_train, y_train)

# %%
# Cross-Validation
param_grid = {
    "criterion": ['gini', 'entropy', 'log_loss'],
    "ccp_alpha": [0.1, 0.01, 0.001, 0.0001],
    "splitter": ['best', 'random'],
    'max_leaf_nodes': list(range(2, 50)),
    'max_depth': list(range(1, 7)),
    'min_samples_split': [2, 3, 4]
}

grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit=True, verbose=3, scoring="roc_auc")

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20736 candidates, totalling 103680 fits
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=random;, score=0.730 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=random;, score=0.752 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=random;, score=0.737 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=random;, score=0.781 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=random;, score=0.717 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=random;, score=0.768 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=random;, score=0.762 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=2, min_samples_split=4, splitter=random;, score=0.748 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=2, splitter=random;, score=0.766 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=random;, score=0.720 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=random;, score=0.725 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=3, splitter=random;, score=0.778 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=random;, score=0.690 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=random;, score=0.695 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=3, min_samples_split=4, splitter=random;, score=0.764 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=random;, score=0.696 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=random;, score=0.772 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=2, splitter=random;, score=0.765 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=random;, score=0.705 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=random;, score=0.748 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=random;, score=0.785 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=3, splitter=random;, score=0.724 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=random;, score=0.707 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=random;, score=0.687 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=4, min_samples_split=4, splitter=random;, score=0.773 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=random;, score=0.711 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=random;, score=0.752 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=random;, score=0.728 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=random;, score=0.775 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=random;, score=0.738 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=random;, score=0.711 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=5, min_samples_split=4, splitter=random;, score=0.738 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=random;, score=0.692 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=random;, score=0.771 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=random;, score=0.751 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=6, min_samples_split=4, splitter=random;, score=0.759 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=random;, score=0.685 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=random;, score=0.778 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=2, splitter=random;, score=0.701 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=random;, score=0.704 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=random;, score=0.741 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=random;, score=0.774 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=random;, score=0.691 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=7, min_samples_split=4, splitter=random;, score=0.778 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=random;, score=0.696 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=random;, score=0.728 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=random;, score=0.766 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=random;, score=0.762 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=random;, score=0.771 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=random;, score=0.723 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=random;, score=0.748 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=8, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=random;, score=0.758 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=3, splitter=random;, score=0.683 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=random;, score=0.765 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=9, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=random;, score=0.732 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=random;, score=0.732 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=2, splitter=random;, score=0.768 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=random;, score=0.720 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=random;, score=0.734 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=random;, score=0.771 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=random;, score=0.786 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=10, min_samples_split=4, splitter=random;, score=0.786 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=random;, score=0.763 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=random;, score=0.765 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=random;, score=0.705 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=random;, score=0.763 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=11, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=random;, score=0.696 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=random;, score=0.692 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=3, splitter=random;, score=0.771 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=random;, score=0.735 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=12, min_samples_split=4, splitter=random;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=13, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=1, max_leaf_nodes=13, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# ...
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=2, splitter=random;, score=0.755 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=2, splitter=random;, score=0.738 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=random;, score=0.785 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=random;, score=0.762 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=random;, score=0.728 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=39, min_samples_split=4, splitter=random;, score=0.778 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=random;, score=0.695 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=2, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=random;, score=0.745 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=random;, score=0.754 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=3, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=best;, score=0.779 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=random;, score=0.776 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=random;, score=0.773 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=random;, score=0.747 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=40, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=41, min_samples_split=2, splitter=best;, score=0.781 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=41, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=41, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.1, criterion=gini, max_depth=2, max_leaf_nodes=41, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 13
#       2 param_grid = {
#       3     "criterion": ['gini', 'entropy', 'log_loss'],
#       4     "ccp_alpha": [0.1, 0.01, 0.001, 0.0001],
#    (...)
#       8     'min_samples_split': [2, 3, 4]
#       9 }
#      11 grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit=True, verbose=3, scoring="roc_auc")
# ---> 13 grid.fit(X_train, y_train)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
dtf = grid.best_estimator_

dtf.fit(X_train, y_train)

y_pred = dtf.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# %%
# Creating data visualizations DT
DTC = DecisionTreeClassifier(criterion='log_loss', ccp_alpha=0.001, splitter='best', max_leaf_nodes=48, min_samples_split=4,max_depth=6)
dt_model = DTC.fit(X_train, y_train)

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(DTC, 
                   feature_names=strokedata.columns,  
                   class_names=target,
                   filled=True)
